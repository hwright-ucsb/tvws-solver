# %%
import skgstat as skg
import math
import itertools
import json
import numpy as np
import pykrige.kriging_tools as kt
from pykrige.rk import Krige
from pykrige.compat import GridSearchCV
from pykrige.ok import OrdinaryKriging
from pykrige.uk import UniversalKriging
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import colors

# %%
# parser function
def parser(fname):
    f = open(fname, "r")
    readings = []
    f.readline()
    f.readline()
    for line in f:
        temp = line.strip("\n").split()
        temp2 = [temp[0], int(temp[1]), float(temp[2]), float(temp[3]), float(temp[4]), float(temp[5]), float(temp[6])]
        readings.append(temp2)
    f.close()
    return readings

# %%
# parser function
def parser_log(fname):
    f = open(fname, "r")
    readings = []
    
    for line in f:
        temp = line.strip("\n").split(",")
                #datetime,lat,long,alt,vel_x,vel_y,vel_z,acc_x,elevation,
                    #source,location,vehicle,device,freq,sig_strength,sig_strength_Dbm
        temp2 = [temp[0], float(temp[1]), float(temp[2]), float(temp[3]), float(temp[4]), float(temp[5]), float(temp[6]), temp[7], float(temp[8]),
                    int(temp[9]), int(temp[10]), int(temp[11]), int(temp[12]), float(temp[13]), float(temp[14]), float(temp[15])]
        readings.append(temp2)
    f.close()
    return readings

# %%
def extract(arr, ind):
    temp = []
    for i in arr:
        temp.append(i[ind])
        
    return temp

# %%
# populate data

# ID, Loop#, Timestamp, Freq, Lat, Long, RF reading
readings = parser_log("../data/channel14_470mhz.log")

# %%
#lats = np.array(extract(readings,4))
#long = np.array(extract(readings,5))
#rf_freqs = np.array(extract(readings,6))
lats = extract(readings,1)
long = extract(readings, 2)
alt = extract(readings, 3)
rf_freqs = extract(readings, 15)

# %%
minlat = min(lats)
maxlat = max(lats)
minlong = min(long)#-116.65
maxlong = max(long)
buff = 0.001
lat_arr = np.arange(minlat-buff,maxlat+buff,abs((minlat-buff)-(maxlat+buff))/30.)
long_arr =np.arange(minlong-buff,maxlong+buff,abs((minlong-buff)-(maxlong+buff))/30.)

# %%
print(maxlong)
print(max(long_arr))
# Out:
# -116.63458025694369
# -116.63466974186241

# %%
#actually generate mesh points for the grid
lat_mesh, long_mesh = np.meshgrid(lat_arr, long_arr)
#lat_mesh = lat_mesh.tolist()
#long_mesh = long_mesh.tolist()

# %%
lat_mesh_flat = list(lat_mesh.flatten())
long_mesh_flat = list(long_mesh.flatten())

# %%
meshdata = plt.figure(figsize=(10,10))  # create a figure object
mesh_ax = meshdata.add_subplot(1, 1, 1)  # create an axes object in the figure
#ax.contour(lat_mesh, long_mesh, z.data, 10)
mesh_ax.scatter(lat_mesh_flat,long_mesh_flat, s=1, color="red")
mesh_ax.scatter(lats,long, s=1, color="blue")

# %% [markdown]
# #### write est points to json

# %%
with open("est_pts.json", "w") as write_file:
    json.dump(list(zip(lat_mesh, long_mesh)), write_file)

# %%
print(min(lat_mesh_flat))
print(max(lat_mesh_flat))
print(min(long_mesh_flat))
print(max(long_mesh_flat))
# Out:
# 33.13632002256799
# 33.1536957819689
# -116.66526480450865
# -116.6356030751958

# %%
print(min(lats))
print(max(lats))
print(min(long))
print(max(long))
print(max(lats)-min(lats))
print(max(long)-min(long))
# Out:
# 33.13632002256799
# 33.153695781968864
# -116.66526480450865
# -116.63458025694369
# 0.01737575940087055
# 0.03068454756495953

# %%
blopop = []
slopop = []

# %%
def exponential_variogram_model(m, d):
    """Exponential model, m is [psill, range, nugget]"""
    psill = float(m[0])
    range_ = float(m[1])
    nugget = float(m[2])
    temp = psill * (1. - np.exp(-d/(range_/3.))) + nugget
    blopop.append(temp)
    return temp

# %%
def wave_variogram_model(m, d):
    """Wave model, m is [psill, range, nugget]"""
    psill = float(m[0])
    range_ = float(m[1])
    nugget = float(m[2])
    #wave intensity
    w = 0.6
    temp = psill * (1. - (w*(math.sin(range_/w)/range_))) + nugget
    slopop = 
    return temp

# %%
math.sin(1/2)
# Out:
# 0.479425538604203

# %%
# Create the ordinary kriging object. Required inputs are the X-coordinates of
# the data points, the Y-coordinates of the data points, and the Z-values of the
# data points. If no variogram model is specified, defaults to a linear variogram
# model. If no variogram model parameters are specified, then the code automatically
# calculates the parameters by fitting the variogram model to the binned
# experimental semivariogram. The verbose kwarg controls code talk-back, and
# the enable_plotting kwarg controls the display of the semivariogram.

#example:
# OK = OrdinaryKriging(data[:, 0], data[:, 1], data[:, 2], 
            #variogram_model='linear', verbose=False, enable_plotting=False)
#sill, range, nugget
vparams = [8.36,0.03,6.0]
OK = OrdinaryKriging(lats, long, rf_freqs, variogram_model='custom', nlags = 10, 
                     variogram_parameters=vparams, variogram_function=wave_variogram_model,
                     verbose=True, enable_plotting=True, coordinates_type='geographic')
#zgaus, ssgaus = OK.execute('grid', lat_mesh_flat, long_mesh_flat)
# Out:
# Plotting Enabled
#
# Initializing variogram model...
# Coordinates type: 'geographic'
#
# Using Custom Variogram Model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-240-d3f4d752a5ac> in <module>
#      14 OK = OrdinaryKriging(lats, long, rf_freqs, variogram_model='custom', nlags = 10,
#      15                      variogram_parameters=vparams, variogram_function=wave_variogram_model,
# ---> 16                      verbose=True, enable_plotting=True, coordinates_type='geographic')
#      17 #zgaus, ssgaus = OK.execute('grid', lat_mesh_flat, long_mesh_flat)
#
# /usr/local/lib/python3.7/site-packages/pykrige/ok.py in __init__(self, x, y, z, variogram_model, variogram_parameters, variogram_function, nlags, weight, anisotropy_scaling, anisotropy_angle, verbose, enable_plotting, enable_statistics, coordinates_type)
#     260                 print("Nugget:", self.variogram_model_parameters[2], '\n')
#     261         if self.enable_plotting:
# --> 262             self.display_variogram_model()
#     263
#     264         if self.verbose:
#
# /usr/local/lib/python3.7/site-packages/pykrige/ok.py in display_variogram_model(self)
#     402         ax.plot(self.lags,
#     403                 self.variogram_function(self.variogram_model_parameters,
# --> 404                                         self.lags), 'k-')
#     405         plt.show()
#     406
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (1,)

# %%
blopop
# Out:
# [array([ 7.17605896,  9.02097859, 10.4128736 , 11.61200394, 12.36709164,
#         12.87056471, 13.25526255, 13.54232956, 13.75515444, 13.91096737])]

# %% [markdown]
# #### universal kriging

# %%
UK = UniversalKriging(lats, long, rf_freqs, variogram_model='exponential',
                     verbose=True, enable_plotting=True)
zu, ssu = UK.execute('grid', lat_mesh_flat, long_mesh_flat)
# Out:
# Plotting Enabled
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Using 'exponential' Variogram Model
# Partial Sill: 2.715789343662278
# Full Sill: 8.360513083482374
# Range: 4.775638192815483e-07
# Nugget: 5.644723739820095
# Calculating statistics on variogram model fit...
# Q1 = 0.4881791108207835
# Q2 = 0.8831187753601052
# cR = 7.402419564006663
#
# Initializing drift terms...
# Executing Universal Kriging...

# %%
minn = 0
maxx = -1000
for i in z:
    tmpmin=min(i.data)
    if tmpmin < minn:
        minn=tmpmin
    tmpmax = max(i.data)
    if tmpmax > maxx:
        maxx=tmpmax

# %%
np.shape(z.data)
# Out:
# (900, 900)

# %%
print(minn)
print(maxx)
print(min(rf_freqs))
print(max(rf_freqs))
# Out:
# -68.02546807473796
# -62.516911650473
# -86.7624022665
# -59.068270098

# %%
ls = [-125.995354, -109.74596445615346, -105.88484194949307 -90.233002]

# %%
figdata = plt.figure(figsize=(10,10))  # create a figure object
ax = figdata.add_subplot(1, 1, 1)  # create an axes object in the figure
#ax.contour(lat_mesh, long_mesh, z.data, 10)
ax.scatter(lats,long, s=1, color="red")
#plt.xlim(minlat, maxlat)
#plt.ylim(-116.65, maxlong)
#figdata.savefig('test1.png', dpi=300)

# %%
#temp save
#Using 'exponential' Variogram Model
#Partial Sill: 6.359999999999999
#Full Sill: 8.36
#Range: 0.009
Nugget: 2.0 good1z = z

# %% [markdown]
# ### ordinary kriging graph

# %%
figdata0 = plt.figure(figsize=(30,30))  # create a figure object
ax0 = figdata0.add_subplot(1, 1, 1)
ax0.set_xlim([minlat-0.0025, maxlat+0.0025])
ax0.set_ylim([minlong-0.0025, maxlong+0.0025])
ax0.contour(lat_mesh_flat,long_mesh_flat,z, levels=15, corner_mask=True)
ax0.scatter(lat_mesh_flat,long_mesh_flat, s=1, color="blue")
ax0.scatter(lats,long, s=1, color="red")

# %%
len(lat_mesh_flat)
# Out:
# 900

# %%
figdata1 = plt.figure(figsize=(10,10))  # create a figure object
ax1 = figdata1.add_subplot(1, 1, 1)
ax1.set_xlim([minlat-0.0025, maxlat+0.0025])
ax1.set_ylim([minlong-0.0025, maxlong+0.0025])
#ax1.contourf(lat_mesh_flat,long_mesh_flat,z, levels=10, cmap='gray')
#ax1.contour(lat_mesh_flat, long_mesh_flat, z, levels=10)
ax1.scatter(lats,long, s=1, color="red")
ax1.pcolormesh(lat_mesh_flat,long_mesh_flat, z, cmap='plasma')

# %%
zmin = np.amin(z.data)
zmax = np.amax(z.data)

plt.imshow(rf_freqs, cmap='hot', interpolation='nearest')#, norm=mcolors.Normalize) #vmax=zmax, vmin=zmin)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-960fd8cc8410> in <module>
#       2 zmax = np.amax(z.data)
#       3
# ----> 4 plt.imshow(rf_freqs, cmap='hot', interpolation='nearest')#, norm=mcolors.Normalize) #vmax=zmax, vmin=zmin)
#       5 plt.show()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2651         vmax=vmax, origin=origin, extent=extent, shape=shape,
#    2652         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
# -> 2653         resample=resample, url=url, data=data, **kwargs)
#    2654     sci(__ret)
#    2655     return __ret
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5470                               resample=resample, **kwargs)
#    5471
# -> 5472         im.set_data(X)
#    5473         im.set_alpha(alpha)
#    5474         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     644         if not (self._A.ndim == 2
#     645                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 646             raise TypeError("Invalid dimensions for image data")
#     647
#     648         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data

# %% [markdown]
# ### universal kriging graph

# %%
figdata1 = plt.figure(figsize=(10,10))  # create a figure object
ax1 = figdata1.add_subplot(1, 1, 1)
ax1.contour(lat_mesh_flat,long_mesh_flat,zu.data, levels=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-a4019c2962ea> in <module>
#       1 figdata1 = plt.figure(figsize=(10,10))  # create a figure object
#       2 ax1 = figdata1.add_subplot(1, 1, 1)
# ----> 3 ax1.contour(lat_mesh_flat,long_mesh_flat,zu.data, levels=15)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    6207     def contour(self, *args, **kwargs):
#    6208         kwargs['filled'] = False
# -> 6209         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6210         self.autoscale_view()
#    6211         return contours
#
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1491                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1492
# -> 1493             x, y, z = self._contour_args(args, kwargs)
#    1494
#    1495             _mask = ma.getmask(z)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1549             args = args[1:]
#    1550         elif Nargs <= 4:
# -> 1551             x, y, z = self._check_xyz(args[:3], kwargs)
#    1552             args = args[3:]
#    1553         else:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1598
#    1599             if nx != Nx:
# -> 1600                 raise TypeError("Length of x must be number of columns in z.")
#    1601
#    1602             if ny != Ny:
#
# TypeError: Length of x must be number of columns in z.

# %%
# Out:
# (1081, 2)

# %% [markdown]
# # semivariogram

# %%
ch_svg = skg.Variogram(coords, rf_freqs, estimator="cressie", model="exponential",
                      dist_func="euclidean", )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e318af6d4f71> in <module>
#       1 ch_svg = skg.Variogram(coords, rf_freqs, estimator="cressie", model="exponential",
# ----> 2                       dist_func="geographic", )
#
# /usr/local/lib/python3.7/site-packages/skgstat/Variogram.py in __init__(self, coordinates, values, estimator, model, dist_func, bin_func, normalize, fit_method, fit_sigma, use_nugget, maxlag, n_lags, verbose, harmonize)
#     171         # set distance calculation function
#     172         self._dist_func = None
# --> 173         self.set_dist_function(func=dist_func)
#     174
#     175         # lags and max lag
#
# /usr/local/lib/python3.7/site-packages/skgstat/Variogram.py in set_dist_function(self, func)
#     516
#     517         # re-calculate distances
# --> 518         self._calc_distances()
#     519
#     520     @property
#
# /usr/local/lib/python3.7/site-packages/skgstat/Variogram.py in _calc_distances(self, force)
#     872             _x = self._X
#     873         # else calculate the distances
# --> 874         self._dist = self._dist_func(_x)
#     875
#     876     def _calc_diff(self, force=False):
#
# /usr/local/lib/python3.7/site-packages/skgstat/Variogram.py in <lambda>(x)
#     508             else:
#     509                 # if not ranks, it has to be a scipy metric
# --> 510                 self._dist_func = lambda x: pdist(X=x, metric=func)
#     511
#     512         elif callable(func):
#
# /usr/local/lib/python3.7/site-packages/scipy/spatial/distance.py in pdist(X, metric, *args, **kwargs)
#    2069                 raise ValueError('Unknown "Test" Distance Metric: %s' % mstr[5:])
#    2070         else:
# -> 2071             raise ValueError('Unknown Distance Metric: %s' % mstr)
#    2072     else:
#    2073         raise TypeError('2nd argument metric must be a string identifier '
#
# ValueError: Unknown Distance Metric: geographic

# %%
print(ch_svg)
# Out:
# exponential Variogram
# ---------------------
# Estimator:         cressie
# Effective Range:   0.00
# Sill:              79.45
# Nugget:            0.00

# %% [markdown]
# # kriging param opt

# %%
# 2D Kring param opt

param_dict = {"method": ["ordinary", "universal"],
              "variogram_model": ["linear", "power", "gaussian", "spherical"],
               "nlags": [4, 6, 8],
              # "weight": [True, False]
              }

estimator = GridSearchCV(Krige(), param_dict, verbose=True)

# dummy data
#X = np.random.randint(0, 400, size=(100, 2)).astype(float)
#y = 5 * np.random.rand(100)

# run the gridsearch
estimator.fit(coords, y=np.array(rf_freqs))


if hasattr(estimator, 'best_score_'):
    print('best_score R² = {:.3f}'.format(estimator.best_score_))
    print('best_params = ', estimator.best_params_)

print('\nCV results::')
if hasattr(estimator, 'cv_results_'):
    for key in ['mean_test_score', 'mean_train_score',
                'param_method', 'param_variogram_model']:
        print(' - {} : {}'.format(key, estimator.cv_results_[key]))

# 3D Kring param opt

param_dict3d = {"method": ["ordinary3d"],
              "variogram_model": ["linear", "power", "gaussian", "spherical"],
              "nlags": [4, 6, 8],
              # "weight": [True, False]
              }

estimator = GridSearchCV(Krige(), param_dict3d, verbose=True)

# dummy data
X3 = np.random.randint(0, 400, size=(100, 3)).astype(float)
y = 5 * np.random.rand(100)

# run the gridsearch
estimator.fit(X=coords, y=y)


if hasattr(estimator, 'best_score_'):
    print('best_score R² = {:.3f}'.format(estimator.best_score_))
    print('best_params = ', estimator.best_params_)

print('\nCV results::')
if hasattr(estimator, 'cv_results_'):
    for key in ['mean_test_score', 'mean_train_score',
                'param_method', 'param_variogram_model']:
        print(' - {} : {}'.format(key, estimator.cv_results_[key]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-4223aa81c051> in <module>
#      14
#      15 # run the gridsearch
# ---> 16 estimator.fit(coords, y=np.array(rf_freqs))
#      17
#      18
#
# NameError: name 'coords' is not defined

# %% [markdown]
# # empirical cdf

# %%
num_bins = 30
counts, bin_edges = np.histogram (rf_freqs, bins=num_bins, normed=False)
cdf = np.cumsum (counts)
plt.plot (bin_edges[1:], cdf/cdf[-1])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Passing normed=False is deprecated, and has no effect. Consider passing the density argument instead.

# %%
for q in [50, 90, 95, 100]:
  print ("{}%% percentile: {}".format (q, np.percentile(rf_freqs, q)))
# Out:
# 50%% percentile: -65.569461316
# 90%% percentile: -62.786619852
# 95%% percentile: -61.995500446
# 100%% percentile: -59.068270098
